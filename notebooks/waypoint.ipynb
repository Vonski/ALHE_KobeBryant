# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
sns.set()
plt.rcParams['figure.figsize'] = [15,28]

# %%
# wczytaj dane i odrzuć wiersze, w których występuje NaN (nie ma shot_made_flag)
data=pd.read_csv("../data/data.csv")
data.dropna(inplace=True)

# %%
X = data[["loc_x", "loc_y"]]
y = data[["shot_made_flag"]]
XX = np.array(X)
yy = np.array(y)

# %%
def rgbToHex(r, g ,b):
    r = np.clip(r, 0, 255)
    g = np.clip(g, 0, 255)
    b = np.clip(b, 0, 255)
    return '#%02x%02x%02x' % (r, g, b)

# %%
def drawRectStat(X, y, cx, cy, ann=False):
    im = np.zeros((901,601))
    im[:,:]=255
    # Create figure and axes
    fig,ax = plt.subplots(1)

    # Display the image
    ax.imshow(im, cmap='gray', vmin=0, vmax=255, extent=[-300, 300, -100, 800])

    hit = np.zeros((901,601))
    every = np.zeros((901,601))
    for i in range(X.shape[0]):
        hit[(X[i][1]+100, X[i][0]+300)]+=y[i]
        every[(X[i][1]+100, X[i][0]+300)]+=1

    mul_x = math.floor(Z.shape[1]/cx)
    mul_y = math.floor(Z.shape[0]/cy)
    for ix in range(cx):
        for iy in range(cy):
            s1 = np.sum(hit[iy*mul_y:(iy+1)*mul_y,ix*mul_x:(ix+1)*mul_x])
            s2 = np.sum(every[iy*mul_y:(iy+1)*mul_y,ix*mul_x:(ix+1)*mul_x])
            if s2:
                rect = patches.Rectangle((ix*mul_x-300,iy*mul_y-100),mul_x,mul_y,facecolor=(1,1-s1/s2,0))
            else:
                rect = patches.Rectangle((ix*mul_x-300,iy*mul_y-100),mul_x,mul_y,facecolor=(0,1,1))
            ax.add_patch(rect)
            annot = ax.annotate(str(round(s1/s2*100,2))+"%", xy=((ix+0.5)*mul_x-300,(iy+0.5)*mul_y-100), xytext=(-20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->"))
            annot.set_visible(ann)
    
    plt.show()

# %%
drawRectStat(XX,yy,7,10, True)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,14,20)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,21,30)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,19,32)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,61,91)

# %%
drawRectStat(XX,yy,65,100)

# %%
drawRectStat(XX,yy,10,3, True)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,9,3, True)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,3,10, True)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,2,20, True)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,141,200)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,12,18)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars

# %%
drawRectStat(XX,yy,24,36)
# Out:
# f:\multimedia\dokumenty\studia\pw_notatki\informatyka\semestr 6\alhe\projekt\localenv\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars
